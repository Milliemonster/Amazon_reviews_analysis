# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import aquire_clean

# %%
rev_df = pd.read_csv('data/top_review_set.csv')
products_df = pd.read_csv('data/vines_top_products.csv', names = ['product_id'])

#separate dfs with vines, verified not vines, not verified or vines
vines = rev_df[rev_df['vine']==1]
verified = rev_df[rev_df['verified_purchase']==1 & (rev_df['vine']==0)]
not_verified = rev_df[(rev_df['verified_purchase']==0) & (rev_df['vine']==0)]

most_helpful = rev_df.sort_values('helpful_votes', ascending = False).reset_index()

most_helpful.head()
# Out:
#    index  customer_id       review_id  product_id product_category  \
# 0  97634     50450046   RPKSX4HW1MXC9  B004Z7H07K             Toys
# 1   5238     51982046  R2ZSQOZ54XLHWT  B00IQ8MVH8             Toys
# 2  99870     49603742  R3H0RI78X4RGOE  B0039S7NO6             Toys
# 3  76733     43232302   ROOY2JR07FYSI  B00ARQW1E0             Toys
# 4  74893     52816730   R7OOH2RSEHHNL  B00CS1WDBI             Toys
#
#    star_rating  helpful_votes  total_votes  vine  verified_purchase  \
# 0          5.0         1442.0       1517.0     0                  0
# 1          3.0         1255.0       1445.0     0                  1
# 2          5.0          704.0        733.0     0                  0
# 3          3.0          665.0        691.0     1                  0
# 4          5.0          646.0        675.0     0                  0
#
#                                      review_headline  \
# 0                           My Son Won't Put it Down
# 1  Read before buying especially if giving as a g...
# 2                                  Fast fun for all!
# 3  Creepy animatronic nightmare-bot.  Daughter lo...
# 4  Great product, great content, and better than ...
#
#                                          review_body  helpful_ratio
# 0  Hi! I am Erin T. and I run a website called th...       0.950560
# 1  I did not open the game so I can not speak to ...       0.868512
# 2  I just bought the game and played it several t...       0.960437
# 3  There is a thin coating of fur and cuteness on...       0.962373
# 4  I wanted to get my 5-year old daughter a table...       0.957037

# %%
most_helpful.loc[0:10, ['helpful_votes', 'star_rating', 'review_body']]
# Out:
#     helpful_votes                                        review_body
# 0          1442.0  Hi! I am Erin T. and I run a website called th...
# 1          1255.0  I did not open the game so I can not speak to ...
# 2           704.0  I just bought the game and played it several t...
# 3           665.0  There is a thin coating of fur and cuteness on...
# 4           646.0  I wanted to get my 5-year old daughter a table...
# 5           538.0  I was really disappointed at first with this p...
# 6           525.0  Not knowing exactly what this game was, we too...
# 7           521.0  This game was recommended to us by another gro...
# 8           455.0  Okay, the cars whiz around the track with amaz...
# 9           407.0  For years in a row as a kid my number one birt...
# 10          395.0  For background before I begin my review, I am ...
