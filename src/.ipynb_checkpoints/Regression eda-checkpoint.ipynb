# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats
import seaborn as sns
import matplotlib.pylab as plt
import datetime
# %matplotlib inline

from pandas.plotting import scatter_matrix
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.graphics.factorplots import interaction_plot
import statsmodels.stats.diagnostic as ssd
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.stats.diagnostic import het_goldfeldquandt

regression_df = pd.read_csv('data/for_regression.csv')
#regression_df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
regression_df.head()
# Out:
#    star_rating  helpful_votes  total_votes  vine  verified_purchase  \
# 0          4.0            3.0          4.0     0                  1
# 1          5.0            0.0          0.0     0                  1
# 2          3.0            0.0          0.0     0                  1
# 3          5.0            0.0          0.0     0                  1
# 4          2.0            0.0          1.0     0                  1
#
#   review_date  review_word_count
# 0  2015-08-31                 64
# 1  2015-08-31                  3
# 2  2015-08-31                 40
# 3  2015-08-31                 12
# 4  2015-08-31                 40

# %%
for i in range (len(regression_df)):
    date = regression_df.loc[i, 'review_date']
    if (len(str(date)) == 10):
        age = (2015 - int(date[0:4]))*365 + (8 - int(date[5:7]))*30.41
        regression_df.loc[i, 'days_old'] = age

regression_df.dropna(inplace = True)

# %%
regression_df.drop('review_date', axis = 1, inplace = True)

# %%
regression_df['helpfulness'] = 2*regression_df['helpful_votes']- regression_df['total_votes']

# %%
regression_df = regression_df[regression_df[total_votes] != 0]

# %%
regression_df.corr()
# Out:
#                    star_rating  helpful_votes  total_votes      vine  \
# star_rating           1.000000      -0.047462    -0.070893 -0.037085
# helpful_votes        -0.047462       1.000000     0.990833  0.074666
# total_votes          -0.070893       0.990833     1.000000  0.080520
# vine                 -0.037085       0.074666     0.080520  1.000000
# verified_purchase     0.138136      -0.088067    -0.097580 -0.642150
# review_word_count    -0.123895       0.221550     0.227422  0.468090
# days_old             -0.065620       0.102613     0.113270  0.260006
# helpfulness          -0.018880       0.987377     0.956929  0.066057
#
#                    verified_purchase  review_word_count  days_old  helpfulness
# star_rating                 0.138136          -0.123895 -0.065620    -0.018880
# helpful_votes              -0.088067           0.221550  0.102613     0.987377
# total_votes                -0.097580           0.227422  0.113270     0.956929
# ...

# %%
sns.pairplot(regression_df)

# %%
regression_df.corr()
# Out:
#                    star_rating  helpful_ratio      vine  verified_purchase  \
# star_rating           1.000000       0.086640  0.118919           0.012409
# helpful_ratio         0.086640       1.000000  0.000656          -0.043024
# vine                  0.118919       0.000656  1.000000          -0.662279
# verified_purchase     0.012409      -0.043024 -0.662279           1.000000
# review_word_count     0.013503       0.120351  0.390415          -0.408424
# days_old              0.020450       0.064251  0.188008          -0.241250
#
#                    review_word_count  days_old
# star_rating                 0.013503  0.020450
# helpful_ratio               0.120351  0.064251
# vine                        0.390415  0.188008
# verified_purchase          -0.408424 -0.241250
# review_word_count           1.000000  0.177063
# days_old                    0.177063  1.000000
