# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

if __name__ == '__main__':
    cols = ['customer_id', 'review_id', 'product_id','product_category', 'star_rating', 'helpful_votes',	'total_votes', 'vine', 'verified_purchase']

    reviews_df = pd.read_csv('data/amazon_reviews_toys.tsv', sep = '\t', usecols = cols, nrows = 1000000, error_bad_lines = False)

    reviews_df.vine = (reviews_df.vine == 'Y')*1
    reviews_df.verified_purchase = (reviews_df.verified_purchase == 'Y')*1
    
    print(reviews_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 9 columns):
# customer_id          1000000 non-null int64
# review_id            1000000 non-null object
# product_id           1000000 non-null object
# product_category     1000000 non-null object
# star_rating          1000000 non-null int64
# helpful_votes        1000000 non-null int64
# total_votes          1000000 non-null int64
# vine                 1000000 non-null int64
# verified_purchase    1000000 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 68.7+ MB
# None

# %%
vines_df = reviews_df.groupby(['product_id']).sum().sort_values('vine', ascending = False).reset_index()

# %%
vines_df.corr()
# Out:
#     product_id  customer_id  star_rating  helpful_votes  total_votes  vine  \
# 0   B00IZ7FH1M   1669539408          205             32           38    31
# 1   B000ID1EYA   1983862076          252             17           22    30
# 2   B00VFZDOC0   1338519784          131            514          670    30
# 3   B00RLFWD2U   1231693669          133              7            7    30
# 4   B00NYZOHWK   2288727671          342             38           54    30
# 5   B00NO86SC4   1407141878          202             15           19    30
# 6   B006ZPO5AK   1274930168          116             32           68    30
# 7   B004P6V2G6   1226533052          129              5           10    30
# 8   B00NCZZU3C   1274757105          151              7            9    30
# 9   B00U3VXZQC   1186453895          138             44           45    30
# 10  B00UUS462A   1198320418          143             13           18    30
# 11  B00TR0C3P4   1258788752          153             36           44    30
# 12  B00RTC159C   1177752451          105             13           14    30
# 13  B003NF7OAI   1443388410          159             12           15    30
# 14  B00NQQTXP8   2419417390          309             44           57    29
# 15  B00NBVTG7I   1408260763          166             28           39    29
# 16  B00S8JGK0Y   1196464492          115              4            4    29
# 17  B00A1XA768   1229725541          138              3            5    29
# 18  B00PQ7MPCS   1524753257          169             14           20    29
# 19  B00MXT4TDK   1491105058          160             46           54    29
# 20  B007XPLI56   2220533603          248             20           23    29
# 21  B00SKBX1NE   1311211894          155            103          180    29
# 22  B00NHQDZ42   1186909996          162            358          398    29
# 23  B00U05Y830   1145959708          122              6           12    29
# 24  B00RLFWO8S   1076565914          128              4            4    29
# 25  B00NQQTXY4   2166055718          264             17           20    29
# 26  B00O59C9WY   1303912159          151             24           32    29
# 27  B00RLFWDRU   1152563392          122              6            7    29
# 28  B00NCZZJ6U   1480789494          160             10           25    29
# 29  B00RTC1EO8   1196222135          117             22           28    29
# 30  B00XRDHG36   1222964756          149            576          618    29
# 31  B00TDP7RZY   1378619036          161            157          204    29
# 32  B00TLENM5G   1239622414          154            356          425    29
# 33  B00N4ONUCE   1247406203          132             51           56    29
# 34  B00TLFTTB6   1419282584          196             41           66    29
# 35  B00FRMJ84A   1221302038          113              1            1    29
# 36  B00M5KD7FI   1365259115          160             17           25    29
# 37  B00TDP7KKQ   1869155716          271            977         1207    29
# 38  B00MXT4TP8   1779406087          250             58           68    28
# 39  B00ND5ZITC   1373345003          171              4           15    28
#
#     verified_purchase
# 0                  16
# 1                  22
# 2                   2
# 3                   0
# 4                  40
# 5                  15
# 6                   1
# 7                   1
# 8                   2
# 9                   1
# 10                  2
# 11                  1
# 12                  0
# 13                  9
# 14                 47
# 15                  9
# 16                  1
# 17                  1
# 18                  8
# 19                  6
# 20                 36
# 21                  3
# 22                  7
# 23                  1
# 24                  1
# 25                 35
# 26                  4
# 27                  1
# 28                  6
# 29                  2
# 30                  4
# 31                  3
# 32                  2
# 33                  1
# 34                  1
# 35                  0
# 36                  7
# 37                 30
# 38                 26
# 39                 10

# %%
vines_top_products = set(vines_df.iloc[:10000, 0])

# %%
len(vines_top_products)
# Out:
# 10000

# %%
top_df = reviews_df[reviews_df['product_id'].isin(vines_top_products)]

# %%
reviews_df.info()
top_df.info()
top_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 9 columns):
# customer_id          1000000 non-null int64
# review_id            1000000 non-null object
# product_id           1000000 non-null object
# product_category     1000000 non-null object
# star_rating          1000000 non-null int64
# helpful_votes        1000000 non-null int64
# total_votes          1000000 non-null int64
# vine                 1000000 non-null int64
# verified_purchase    1000000 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 68.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47607 entries, 18 to 999989
# Data columns (total 9 columns):
# customer_id          47607 non-null int64
# review_id            47607 non-null object
# product_id           47607 non-null object
# product_category     47607 non-null object
# star_rating          47607 non-null int64
# helpful_votes        47607 non-null int64
# total_votes          47607 non-null int64
# vine                 47607 non-null int64
# verified_purchase    47607 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 3.6+ MB
#         customer_id   star_rating  helpful_votes   total_votes          vine  \
# count  4.760700e+04  47607.000000   47607.000000  47607.000000  47607.000000
# mean   2.634914e+07      4.304829       0.877980      1.129267      0.152835
# std    1.663486e+07      1.171475       6.440411      6.962178      0.359832
# min    1.103300e+04      1.000000       0.000000      0.000000      0.000000
# 25%    1.253748e+07      4.000000       0.000000      0.000000      0.000000
# 50%    2.483751e+07      5.000000       0.000000      0.000000      0.000000
# 75%    4.223764e+07      5.000000       0.000000      1.000000      0.000000
# max    5.309583e+07      5.000000     442.000000    453.000000      1.000000
#
#        verified_purchase
# count       47607.000000
# mean            0.783120
# std             0.412124
# min             0.000000
# 25%             1.000000
# 50%             1.000000
# 75%             1.000000
# max             1.000000

# %%
sns.pairplot(reviews_df)
plt.show()
